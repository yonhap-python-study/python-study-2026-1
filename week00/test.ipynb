# %% [markdown]
# <a href="https://colab.research.google.com/github/yonhap-python-study/python-study-2026-1/blob/main/week00/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================
# 문제: 짝수의 합 구하기
# ================================

def solution(numbers):
    """
    정수 리스트 numbers가 주어질 때,
    짝수들의 합을 반환하시오.
    """
    # 여기에 코드 작성
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total


# ================================
# 자동 채점 코드 (수정 금지)
# ================================

def run_tests():
    test_cases = [
        ([1, 2, 3, 4], 6),
        ([2, 4, 6, 8], 20),
        ([1, 3, 5], 0),
        ([10], 10),
        ([], 0),
    ]

    passed = 0

    for i, (input_data, expected) in enumerate(test_cases):
        result = solution(input_data)
        if result == expected:
            print(f"✅ Test {i+1} 통과")
            passed += 1
        else:
            print(f"❌ Test {i+1} 실패 | 입력: {input_data} | 예상값: {expected} | 출력값: {result}")

    print("\n===================")
    print(f"총 {passed}/{len(test_cases)} 통과")

    if passed == len(test_cases):
        print("🎉 모든 테스트 통과!")
    else:
        print("⚠️ 다시 확인하세요.")


# 실행
run_tests()
